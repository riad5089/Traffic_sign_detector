# %%
 # !pip install -Uqq fastai

# %%
from fastai.vision.all import *

# %%
# %cd /content/drive/MyDrive/Mastercourse_Project
# Out:
# [Errno 2] No such file or directory: '/content/drive/MyDrive/Mastercourse_Project'
# /content

# %%
version = 1
img_path = 'test_images'
model_path = f'/content/drive/MyDrive/Mastercourse_Project/Traffic sign detection/models/traffic_sign-recognizer-v{version}.pkl'

# %%
model = load_learner(model_path)

# %%
img = Image.open("/content/drive/MyDrive/Mastercourse_Project/Traffic sign detection/test_image/download (2).png")
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=P size=128x128>

# %%
model.predict("/content/drive/MyDrive/Mastercourse_Project/Traffic sign detection/test_image/download (2).png")
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Warning Signs',
#  tensor(17),
#  tensor([5.1473e-05, 1.5455e-09, 9.2527e-07, 1.1975e-07, 4.0731e-09, 2.6686e-08,
#          1.5115e-08, 2.0013e-08, 8.6605e-09, 3.6297e-05, 1.3301e-08, 6.5688e-09,
#          9.3817e-09, 2.3969e-08, 9.3892e-09, 4.3234e-07, 1.2417e-05, 9.9990e-01]))

# %%
img = Image.open("/content/drive/MyDrive/Mastercourse_Project/Traffic sign detection/test_image/download (3).jpg")
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=92x122>

# %%
model.predict('/content/drive/MyDrive/Mastercourse_Project/Traffic sign detection/test_image/download (3).jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('School Zone Signs',
#  tensor(14),
#  tensor([1.3682e-04, 5.5579e-06, 8.4070e-06, 1.4528e-05, 4.6088e-05, 9.9267e-07,
#          1.4207e-04, 2.0480e-04, 2.7220e-04, 4.0656e-06, 8.1271e-06, 2.3880e-04,
#          2.3238e-04, 3.3769e-05, 9.9752e-01, 1.9886e-04, 2.7649e-05, 9.0906e-04]))

# %%
img = Image.open("/content/drive/MyDrive/Mastercourse_Project/Traffic sign detection/test_image/download.png")
img.to_thumb(128,128)

# %%
model.predict('/content/drive/MyDrive/Mastercourse_Project/Traffic sign detection/test_image/download.png')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Construction Signs',
#  tensor(0),
#  tensor([0.2238, 0.0011, 0.0002, 0.0110, 0.0128, 0.0011, 0.1105, 0.1266, 0.1756,
#          0.0909, 0.0030, 0.0056, 0.0068, 0.0027, 0.0906, 0.0039, 0.0016, 0.1322]))
